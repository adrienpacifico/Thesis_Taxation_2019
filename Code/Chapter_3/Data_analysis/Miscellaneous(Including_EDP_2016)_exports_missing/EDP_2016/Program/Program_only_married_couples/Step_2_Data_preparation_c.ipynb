# %% [markdown]
# We want to isolate households with two parents living under civil union with children being over (or not) 21/25 yo.

# %%
import datetime
start_time = datetime.datetime.now(); print(start_time)
# Out:
# 2019-01-31 15:06:43.212425

# %%
# %matplotlib inline

# %%
secret = False #Will be put to True for a CASD export

# %%
from IPython.display import display
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd ; pd.set_option("display.max_columns",200)
import pickle

# %%
import pickle
pickle_year_variable_path = "C:/Users/IMPTEMP_A_PACIFIC/Desktop/EDP_2016/Program/Program_only_married_couples/year_variable/"
year =  pickle.load(open(pickle_year_variable_path+"year_variable.p",'rb')); print(year)
# Out:
# 2011

# %%
store_path = 'C:/Users/IMPTEMP_A_PACIFIC/Desktop/EDP_2016/Data/hdf/edp_2016_final.h5'
result_path = u"C:/Users/IMPTEMP_A_PACIFIC/Desktop/EDP_2016/Program/Program_only_married_couples/hdf_married_couples/"
Store = pd.HDFStore(store_path)

# %%
Store.close()

# %%
fiscr = pd.read_hdf(result_path+"married_couples_step_1.h5", "fiscr")

# %%
fiscr.describe()
# Out:
#        AN_FISC_2011  AN_REVENU_2011       REG_2011      TU10_2011  \
# count      790495.0        790495.0  790495.000000  790495.000000
# mean         2012.0          2011.0      48.157229       3.783992
# std             0.0             0.0      28.187345       3.128847
# min          2012.0          2011.0       1.000000       0.000000
# 25%          2012.0          2011.0      24.000000       0.000000
# 50%          2012.0          2011.0      43.000000       4.000000
# 75%          2012.0          2011.0      73.000000       7.000000
# max          2012.0          2011.0      94.000000       8.000000
#
#        NBFOYM_2011   NBPERSM_2011    INF14M_2011    SUP14M_2011  NBERAM_2011  \
# count     790495.0  790495.000000  790495.000000  790495.000000     790495.0
# mean           1.0       3.191510       0.880308       2.311202          0.0
# std            0.0       1.234718       1.092746       0.657571          0.0
# min            1.0       2.000000       0.000000       2.000000          0.0
# 25%            1.0       2.000000       0.000000       2.000000          0.0
# 50%            1.0       3.000000       0.000000       2.000000          0.0
# 75%            1.0       4.000000       2.000000       2.000000          0.0
# max            1.0      12.000000       6.000000       8.000000          0.0
#
#           NB_UC_2011     AGERF_2011    SEXERF_2011    OCCTYP_2011  \
# count  790495.000000  790495.000000  790495.000000  790495.000000
# mean        1.919694      52.144593       1.003357       1.267499
# std         0.447520      15.026035       0.057846       0.625958
# min         1.500000       2.000000       1.000000       1.000000
# 25%         1.500000      40.000000       1.000000       1.000000
# 50%         1.800000      49.000000       1.000000       1.000000
# 75%         2.100000      64.000000       1.000000       1.000000
# max         5.700000     104.000000       2.000000       3.000000
#
#         TYPMEN9_2011  NB_ALLOC_CNAF_2011  NB_ALLOC_CNAV_2011  \
# count  790495.000000       780371.000000       780371.000000
# mean       36.819775            0.460786            0.002731
# std         5.984328            0.525202            0.055632
# min        30.000000            0.000000            0.000000
# 25%        30.000000            0.000000            0.000000
# 50%        41.000000            0.000000            0.000000
# 75%        42.000000            1.000000            0.000000
# max        43.000000            5.000000            2.000000
#
#        NB_ALLOC_MSAF_2011  NB_ALLOC_MSAV_2011  NIVVIEM_2011   CENTILE_2011  \
# count       780371.000000       780371.000000  7.803710e+05  780371.000000
# mean             0.020727            0.000246  2.605463e+04      58.222654
# std              0.143286            0.016635  2.569687e+04      27.477678
# min              0.000000            0.000000 -6.939080e+05       1.000000
# 25%     0.000000e+00     361.000000     689.000000       0.000000
# 50%     0.000000e+00     597.000000    1067.000000     739.000000
# 75%     1.000000e+00     902.000000    1509.000000    1320.000000
# max     8.826387e+06   14588.000000  168407.000000  168407.000000
#
#           CRDSM_2011  CRDSSALM_2011   CSGPATM_2011  CSGVALM_2011  \
# count  790495.000000  790495.000000  790495.000000  7.904950e+05
# mean      259.261082     181.499672     225.217819  1.061450e+02
# std       244.778798     222.578180    1599.107564  7.737062e+03
# min         0.000000       0.000000       0.000000  0.000000e+00
# 25%       146.000000       0.000000       0.000000  0.000000e+00
# 50%       224.000000     154.000000       0.000000  0.000000e+00
# 75%       316.000000     275.000000       0.000000  1.000000e+00
# max     35087.000000   35087.000000  636545.000000  5.853288e+06
#
#         CSGIMPM_2011     CSGDM_2011  CSGDSALM_2011  PRODUITFIN_2011  \
# count  790495.000000  790495.000000  790495.000000    780371.000000
# mean      338.217656    2533.862169    1850.999412      3073.096437
# std       796.325077    2505.090687    2270.082284      6542.687443
# min         0.000000       0.000000       0.000000        31.000000
# 25%        53.000000    1324.000000       0.000000       595.000000
# 50%       128.000000    2152.000000    1570.000000      1302.000000
# 75%       325.000000    3123.000000    2805.000000      3085.000000
# max     73626.000000  357852.000000  357852.000000    586650.000000
#
#           ZPPEM_2011    ZQUOM_2011    ZDIVM_2011    ZGLOM_2011     ZAVFM_2011  \
# count  780371.000000  7.904950e+05  7.803710e+05  7.803710e+05  780371.000000
# mean       88.337675  3.827963e+01  3.485647e+02  6.066828e+01       1.635539
# std       235.647772  2.589575e+03  3.846817e+04  6.616558e+03      77.086975
# min         0.000000  0.000000e+00 -1.826723e+06  0.000000e+00       0.000000
# 25%         0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 50%         0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 75%         0.000000  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# max      2456.000000  1.003583e+06  1.993224e+07  3.267715e+06   29157.000000
#
#        ZIMPFORM_2011     NBPAC_2011  GARDEM_2011  SERVDOMM_2011  \
# count   7.904950e+05  790495.000000          0.0            0.0
# mean    1.003085e+02       1.191510          NaN            NaN
# std     7.138718e+03       1.234718          NaN            NaN
# min     0.000000e+00       0.000000          NaN            NaN
# 25%     0.000000e+00       0.000000          NaN            NaN
# 50%     0.000000e+00       1.000000          NaN            NaN
# 75%     0.000000e+00       2.000000          NaN            NaN
# max     3.787126e+06      10.000000          NaN            NaN
#
#        ZIMPOM_DECL_2011  ZIMPOM_ANC_2011  ZIMPOM_ANC_DECL_2011  \
# count               0.0              0.0                   0.0
# mean                NaN              NaN                   NaN
# std                 NaN              NaN                   NaN
# min                 NaN              NaN                   NaN
# 25%                 NaN              NaN                   NaN
# 50%                 NaN              NaN                   NaN
# 75%                 NaN              NaN                   NaN
# max                 NaN              NaN                   NaN
#
#        ZAVFM_DECL_2011  ZTHABM_DECL_2011  AN_FISC_2014  AN_REVENU_2014  \
# count              0.0               0.0      790495.0        790495.0
# mean               NaN               NaN        2015.0          2014.0
# std                NaN               NaN           0.0             0.0
# min                NaN               NaN        2015.0          2014.0
# 25%                NaN               NaN        2015.0          2014.0
.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    0.000000e+00  0.000000e+00      79.000000    1367.000000
# 50%    0.000000e+00  1.000000e+00     174.000000    2271.000000
# 75%    0.000000e+00  4.400000e+01     404.000000    3353.000000
# max    4.400160e+06  6.272161e+06   78454.000000  445455.000000
#
#        CSGDSALM_2014  PRODUITFIN_2014     ZPPEM_2014    ZQUOM_2014  \
# count  790495.000000    780371.000000  790495.000000  7.904950e+05
# mean     1920.470902      2805.992022      66.878295  5.226190e+01
# std      2476.291894      5370.831552     202.129319  4.745053e+03
# min         0.000000        23.000000       0.000000  0.000000e+00
# 25%         0.000000       635.000000       0.000000  0.000000e+00
# 50%      1540.000000      1327.000000       0.000000  0.000000e+00
# 75%      2995.000000      2956.000000       0.000000  0.000000e+00
# max    275589.000000    506452.000000    2960.000000  2.649774e+06
#
#          ZDIVM_2014    ZGLOM_2014    ZAVFM_2014  ZIMPFORM_2014     NBPAC_2014  \
# count  7.904950e+05  7.904950e+05  7.904950e+05  790495.000000  790495.000000
# mean   8.400827e+02  7.622222e+01  2.176559e+02      14.781987       1.212458
# std    6.287040e+04  1.117717e+04  3.918237e+03    1635.442419       1.259074
# min   -3.882279e+06  0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    0.000000e+00  0.000000e+00  0.000000e+00       0.000000       0.000000
# 50%    0.000000e+00  0.000000e+00  1.000000e+00       0.000000       1.000000
# 75%    0.000000e+00  0.000000e+00  3.400000e+01       0.000000       2.000000
# max    3.365565e+07  9.402846e+06  2.150477e+06  838972.000000       8.000000
#
#         GARDEM_2014  SERVDOMM_2014  ZIMPOM_DECL_2014  ZIMPOM_ANC_2014  \
# count  7.904950e+05  790495.000000      7.904950e+05     7.904950e+05
# mean   2.109461e+02     532.313068      3.433927e+03     3.508225e+03
# std    3.495850e+04    2492.996403      1.818540e+04     2.103956e+04
# min    0.000000e+00       0.000000     -8.977600e+04    -1.145600e+05
# 25%    0.000000e+00       0.000000      0.000000e+00     0.000000e+00
# 50%    0.000000e+00       0.000000      8.600000e+02     1.147000e+03
# 75%    0.000000e+00       0.000000      3.218000e+03     3.165000e+03
# max    3.107402e+07  843257.000000      9.942866e+06     9.174705e+06
#
#        ZIMPOM_ANC_DECL_2014  ZAVFM_DECL_2014  ZTHABM_DECL_2014          index
# count          7.904950e+05     7.904950e+05     790495.000000  790495.000000
# mean           3.541509e+03     2.415988e+02        737.772352  404820.237721
# std            2.012622e+04     1.058647e+04        574.354137  233107.926985
# min           -5.117800e+04     0.000000e+00          0.000000       0.000000
# 25%            0.000000e+00     0.000000e+00        387.000000  203326.500000
# 50%            8.710000e+02     1.000000e+00        639.000000  404999.000000
# 75%            3.234000e+03     3.200000e+01        963.000000  606660.500000
# max            9.953495e+06     8.508504e+06      15990.000000  808323.000000

# %% [markdown]
# ### Add individual variables

# %% [markdown]
# Here we are going to add individualized variables to the tax-household fiscr Database.

# %% [markdown]
# ### Get parents individualized variables (age and `ID_DIFF` --individual unique identifier )

# %%
## FISC_REVDET contains individualized income in multiple categories (wage, retirement income, etc)
fisc_revdet_2011 = pd.read_hdf( store_path,"FISC_REVDET_{}".format(year+1) ); print(fisc_revdet_2011.shape)
fisc_revdet_2014 = pd.read_hdf( store_path,"FISC_REVDET_{}".format(2014+1) );print(fisc_revdet_2014.shape)
# Out:
# (5194667, 12)
# (5418389, 12)

# %% [markdown]
# We have over 5 millions individuals income in the fiscal sources of the database each year.

# %% [markdown]
# #### We merge year 2011 individual income with year 2014 on a key unique to an individual.

# %%
fisc_revdet = pd.merge(fisc_revdet_2011, fisc_revdet_2014, on = [
    "ID_FISC_FOY_DIFF","ORDREFIP", "TYPE_FISC"], suffixes = ("_2011", "_2014"))
fisc_revdet.shape
# Out:
# (3260952, 21)

# %% [markdown]
# We loose 2 millions individuals that are not present both in 2011 and 2014.

# %% [markdown]
# #### Merge with FISC_INDIVIDU table
#
# Sadly, there is no key to merge directly tax households data (`FISC_REVENU`) (containing income) on individualize tax income data `FISC_REVDET`.
# We thus have to use tax individual data `FISC_INDIVIDU` that do not contain income in order to have a unique key to merge `FISC_REVDET` with `FISC_REVENU`.
#
# To develop a bit:
#  * `FISC_REVDET` contains the `ID_FISC_LOG_DIFF` that is a key unique to each **household** (reference unit in this study)
#  * `FISC_INDIVIDU` that contains `"ID_FISC_FOY_DIFF","ORDREFIP", "TYPE_FISC"` keys unique for each individual, and `ID_FISC_LOG_DIFF`.
#  * `FISC_REVENU` that contains `"ID_FISC_FOY_DIFF","ORDREFIP", "TYPE_FISC"`
#
# We thus have to merge the three tables in order to merge `FISC_REVDET` with `FISC_REVENU` (after doing some groupbys over households on the `FISC_REVDET` database ).

# %%
fisc_revdet.TYPE_FISC = fisc_revdet.TYPE_FISC.astype("str")

# %%
fisci = pd.read_hdf( store_path,"FISC_INDIVIDU_{}".format(2011+1))

# %%
fisci = pd.read_hdf( store_path,"FISC_INDIVIDU_{}".format(2011+1))
fisci = fisci[fisci.ID_FISC_LOG_DIFF.isin(fiscr.ID_FISC_LOG_DIFF)]

# %%
# %%time
print(fisci.shape)
fisc_i_revdet = pd.merge(fisc_revdet, fisci, on=["ID_FISC_FOY_DIFF", "ORDREFIP", "TYPE_FISC"], 
                                 how = "right") #keep  all fisci obs, and only matching fisc_revdet keys
print(fisc_i_revdet.shape)
# Out:
# (2522873, 32)
# (2522873, 50)
# Wall time: 7.46 s

# %%
fisc_i_revdet.YSALI_2011.dropna().hist(bins = 1000); plt.xlim(0, 250_000)
# Out:
# (0, 250000)

# %%
fisci.shape
# Out:
# (2522873, 32)

# %%
df = fisc_i_revdet

# %%
## TODO check for duplicates (same NBPERS as line of obs)
df.sort_values("ID_FISC_LOG_DIFF").head()[:0]
# Out:
# Empty DataFrame
# Columns: [AN_FISC_2011, ID_FISC_FOY_DIFF, ORDREFIP, TYPE_FISC, REV_PRINC_2011, YSALI_2011, YCHOI_2011, YRSTI_2011, YALRI_2011, YRAGI_2011, YBICI_2011, YBNCI_2011, AN_FISC_2014, REV_PRINC_2014, YSALI_2014, YCHOI_2014, YRSTI_2014, YALRI_2014, YRAGI_2014, YBICI_2014, YBNCI_2014, ID_DIFF, AN_FISC, ID_FISC_LOG_DIFF, SEXE, JNAIS, MNAIS, ANAIS, CODNAIS, CIDECI, ZOXYZD, DACOED, T_CHARGE, CNCOIPV, CSDEP, CNE1, COM_NSCAT, COM_SCAT1, COM_SCAT2, I_FISC_LOGEMENT, I_FISC_REVENU, LIEN_FAMILIAL, NBPTR, I_FISC_DECES, TYPE_DECL, I_FISC_REVDET, TYPE_PRES, POIDS_FIDELI, ID_FISC_FOY_CONJ, ID_FISC_ADR_DIFF]
# Index: []

# %%
df.columns[4:]
# Out:
# Index(['REV_PRINC_2011', 'YSALI_2011', 'YCHOI_2011', 'YRSTI_2011',
#        'YALRI_2011', 'YRAGI_2011', 'YBICI_2011', 'YBNCI_2011', 'AN_FISC_2014',
#        'REV_PRINC_2014', 'YSALI_2014', 'YCHOI_2014', 'YRSTI_2014',
#        'YALRI_2014', 'YRAGI_2014', 'YBICI_2014', 'YBNCI_2014', 'ID_DIFF',
#        'AN_FISC', 'ID_FISC_LOG_DIFF', 'SEXE', 'JNAIS', 'MNAIS', 'ANAIS',
#        'CODNAIS', 'CIDECI', 'ZOXYZD', 'DACOED', 'T_CHARGE', 'CNCOIPV', 'CSDEP',
#        'CNE1', 'COM_NSCAT', 'COM_SCAT1', 'COM_SCAT2', 'I_FISC_LOGEMENT',
#        'I_FISC_REVENU', 'LIEN_FAMILIAL', 'NBPTR', 'I_FISC_DECES', 'TYPE_DECL',
#        'I_FISC_REVDET', 'TYPE_PRES', 'POIDS_FIDELI', 'ID_FISC_FOY_CONJ',
#        'ID_FISC_ADR_DIFF'],
#       dtype='object')

# %%
individual_income_variables = ['REV_PRINC_2011', 'YSALI_2011', 'YCHOI_2011', 'YRSTI_2011',
       'YALRI_2011', 'YRAGI_2011', 'YBICI_2011', 'YBNCI_2011', 'AN_FISC_2014',
       'REV_PRINC_2014', 'YSALI_2014', 'YCHOI_2014', 'YRSTI_2014',
       'YALRI_2014', 'YRAGI_2014', 'YBICI_2014', 'YBNCI_2014',]

# %%
## Create a variable for the father and the mother for each individualized income
for col in individual_income_variables:
    df.loc[
        (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 1)),"{}_father".format(col)
    ] = df[col]

    df.loc[
        (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2)),"{}_mother".format(col)
    ] = df[col]

# %%
df.head()

# %%
parents_income_var = [col + "_{}".format(sex_parent) for col in individual_income_variables
                    for sex_parent in ["father", "mother"]]

# %%
df_grpby = df.groupby("ID_FISC_LOG_DIFF")[parents_income_var].sum()

# %%
df_grpby.YSALI_2011_father.isna().value_counts(dropna = False)
# Out:
# False    705556
# True      84939
# Name: YSALI_2011_father, dtype: int64

# %% [markdown]
# ##### Age_mother, Age_father

# %%
df.loc[
          (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 1)),
"Age_father"] = (2011 - df.ANAIS)

df.loc[
          (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2)),
"Age_mother"] = (2011 - df.ANAIS)

# %%
df.Age_father.dropna().hist(bins = 150, alpha = 0.4, label = "Father")
df.Age_mother.dropna().hist(bins = 150, alpha = 0.4,label = "Mother"); plt.legend()

# %%
df[(df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 1))].Age_father.isna().value_counts()
# Out:
# False    791117
# Name: Age_father, dtype: int64

# %%
df[(df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2))].YSALI_2011_mother.isna().value_counts()
# Out:
# False    705634
# True      84242
# Name: YSALI_2011_mother, dtype: int64

# %%
fisc_revdet.query("ID_FISC_FOY_DIFF == 1000222 ").head()
# Out:
#         AN_FISC_2011  ID_FISC_FOY_DIFF ORDREFIP TYPE_FISC  REV_PRINC_2011  \
# 588965          2012           1000222        A         1               1
# 588966          2012           1000222        A         2               1
# 588967          2012           1000222        A         3               0
#
#         YSALI_2011  YCHOI_2011  YRSTI_2011  YALRI_2011  YRAGI_2011  \
# 588965       62581           0           0           0         0.0
# 588966       28213           0           0           0         0.0
# 588967           0           0           0           0         0.0
#
#         YBICI_2011  YBNCI_2011  AN_FISC_2014  REV_PRINC_2014  YSALI_2014  \
# 588965         0.0         0.0          2015               1       66647
# 588966         0.0         0.0          2015               1       30421
# 588967         0.0         0.0          2015               0           0
#
#         YCHOI_2014  YRSTI_2014  YALRI_2014  YRAGI_2014  YBICI_2014  YBNCI_2014
# 588965           0           0           0         0.0         0.0         0.0
# 588966           0           0           0         0.0         0.0         0.0
# 588967           0           0           0         0.0         0.0         0.0

# %%
fisci.query("ID_FISC_FOY_DIFF == 1000223 ")
# Out:
#       ID_DIFF  AN_FISC  ID_FISC_FOY_DIFF  ID_FISC_LOG_DIFF ORDREFIP TYPE_FISC  \
# 333       NaN     2012           1000223         2481117.0        B         1
# 334       NaN     2012           1000223         2481117.0        B         2
# 335  931696.0     2012           1000223         2481117.0        B         A
#
#      SEXE  JNAIS  MNAIS   ANAIS CODNAIS CIDECI ZOXYZD      DACOED T_CHARGE  \
# 333   1.0    4.0   12.0  1965.0   33522      M      X  12072003.0      NaN
# 334   2.0    1.0   11.0  1967.0   33063      M      X  12072003.0      NaN
# 335   NaN    NaN    NaN  2000.0     NaN      A    NaN         NaN        F
#
#     CNCOIPV CSDEP  CNE1  COM_NSCAT  COM_SCAT1  COM_SCAT2  I_FISC_LOGEMENT  \
# 333     NaN    33   122        NaN        NaN        NaN                1
# 334     NaN    33   122        NaN        NaN        NaN                1
# 335     NaN    33   122        NaN        NaN        NaN                1
#
#      I_FISC_REVENU  LIEN_FAMILIAL  NBPTR  I_FISC_DECES  TYPE_DECL  \
# 333              1            NaN    NaN           NaN          1
# 334              1            NaN    NaN           NaN          1
# 335              1            NaN    NaN           NaN          1
#
#      I_FISC_REVDET  TYPE_PRES  POIDS_FIDELI  ID_FISC_FOY_CONJ  \
# 333              1          0      0.000000               NaN
# 334              1          0      0.000000               NaN
# 335              0          1     33.602924               NaN
#
#      ID_FISC_ADR_DIFF
# 333            412777
# 334            412777
# 335            412777

# %%
df[(df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2))][df[(df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2))].YSALI_2014_mother.isna()]

# %% [markdown]
# #### ID_DIFF father mother

# %%
df.loc[
          (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 1)),
"ID_DIFF_father"] = df.ID_DIFF

df.loc[
          (df.TYPE_FISC.isin(["1","2"]) & (df.SEXE == 2)),
"ID_DIFF_mother"] = df.ID_DIFF

# %%
fisci_to_merge = df[["Age_father", "Age_mother",
                     "ID_DIFF_father","ID_DIFF_mother",
                     "ID_FISC_LOG_DIFF"]
                   + parents_income_var ].groupby("ID_FISC_LOG_DIFF").first()
fisci_to_merge.head()

# %%
fisci_to_merge.Age_mother.isnull().value_counts()
# Out:
# False    788906
# True       1589
# Name: Age_mother, dtype: int64

# %%
fisci_to_merge.Age_father.isnull().value_counts()
# Out:
# False    789612
# True        883
# Name: Age_father, dtype: int64

# %%
merge = pd.merge(fiscr, 
                 fisci_to_merge.reset_index(), 
                 on = "ID_FISC_LOG_DIFF")

# %%
fiscr.shape
# Out:
# (790495, 202)

# %%
merge.shape
# Out:
# (790495, 240)

# %%
fiscr = merge

# %%
del(fisci, fisci_to_merge)

# %%
fiscr[fiscr.YSALI_2011_father.isnull()| fiscr.YSALI_2014_father.isnull()].shape
# Out:
# (84939, 240)

# %% [markdown]
# We have 66231 fiscal-households over 707395 (9.3%)  for which we did not have the fiscal-households individualized income.
#
#
# \# TODO: Find why

# %%
fiscr["No_individual_income"] = fiscr.YSALI_2011_father.isnull()

# %% [markdown]
# ### Age children

# %%
fisc_individu_2011 = pd.read_hdf( store_path,"FISC_INDIVIDU_{}".format(2011+1) )

# %%
fisci_select = fisc_individu_2011[fisc_individu_2011.TYPE_FISC.isin(["3",'4','5','6','A','B','C','D','E', 'F'])]

# %%
fisci_select["Age_enfant"] = 2011-fisci_select.ANAIS
# Out:
# C:\Users\IMPTEMP_A_PACIFIC\Desktop\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
grpby_fisci = fisci_select[["ID_FISC_LOG_DIFF","Age_enfant"]].groupby("ID_FISC_LOG_DIFF")

# %%
df_grpby_fisci = pd.DataFrame()
df_grpby_fisci["Age_eldest_child"] = grpby_fisci.Age_enfant.max()
df_grpby_fisci["Age_youngest_child"] = grpby_fisci.Age_enfant.min()
df_grpby_fisci["Age_child_mean"] = grpby_fisci.Age_enfant.mean()

# %%
merge = pd.merge(fiscr, df_grpby_fisci.reset_index(),on = "ID_FISC_LOG_DIFF", how = "left")

# %%
fiscr = merge

# %% [markdown]
# ## Checks

# %% [markdown]
# ### Number of dependent child is the same in fisci and in fiscr

# %%
fisc_individu_2011 = pd.read_hdf( store_path,"FISC_INDIVIDU_{}".format(2011+1) )
fisc_individu_2014 = pd.read_hdf( store_path,"FISC_INDIVIDU_{}".format(2014+1) )

# %%
# %%time
### Keep only observations still in the database
fisc_individu_2011 = fisc_individu_2011[fisc_individu_2011.ID_FISC_LOG_DIFF.isin(
   fiscr.ID_FISC_LOG_DIFF.values)]
fisc_individu_2014 = fisc_individu_2014[fisc_individu_2014.ID_FISC_LOG_DIFF.isin(
   fiscr.ID_FISC_LOG_DIFF.values)]
#fisc_individu_2014 = fisc_individu_2014[fisc_individu_2014.isin(fiscr.ID_FISC_LOG_DIFF)]
# Out:
# Wall time: 7.42 s

# %%
dependent_values_list = ["3",'4','5','6','A','B','C','D','E', 'F']

# %%
fisc_individu_2011["Dependent"] = fisc_individu_2011.TYPE_FISC.isin(
    dependent_values_list)
fisc_individu_2014["Dependent"] = fisc_individu_2014.TYPE_FISC.isin(
   dependent_values_list)

# %%
grpby_2011 = fisc_individu_2011[["ID_FISC_LOG_DIFF","Dependent"]].groupby("ID_FISC_LOG_DIFF")
grpby_2014 = fisc_individu_2014[["ID_FISC_LOG_DIFF","Dependent"]].groupby("ID_FISC_LOG_DIFF")

grpby_fisci_2011 = pd.DataFrame()
grpby_fisci_2011["Nb_dependent"] = grpby_2011["Dependent"].sum()
grpby_fisci_2011["Nb_pers_household"] =  grpby_2011["Dependent"].count()

grpby_fisci_2014 = pd.DataFrame()
grpby_fisci_2014["Nb_dependent"] = grpby_2014["Dependent"].sum()
grpby_fisci_2014["Nb_pers_household"] =  grpby_2014["Dependent"].count()

# %%
merge = pd.merge(fiscr, grpby_fisci_2011.reset_index(), on = "ID_FISC_LOG_DIFF")
merge = pd.merge(merge, grpby_fisci_2014.reset_index(), on = "ID_FISC_LOG_DIFF", 
                 suffixes = ("_2011","_2014"))

# %%
merge.Nb_dependent_2011.fillna(0, inplace = True)
merge.Nb_dependent_2014.fillna(0, inplace = True)

# %%
(merge.Nb_dependent_2011 == merge.NBPAC_2011).value_counts() ## 74 households that we drop TODO : find why ?
# Out:
# True     790421
# False        74
# dtype: int64

# %%
(merge.Nb_dependent_2014 == merge.NBPAC_2014).value_counts() ##
# Out:
# True     790486
# False         9
# dtype: int64

# %%
merge.shape
# Out:
# (790495, 248)

# %%
merge = merge.query("(Nb_dependent_2014==NBPAC_2014) & (Nb_dependent_2011==NBPAC_2011)")

# %%
merge.shape
# Out:
# (790413, 248)

# %%
assert np.all(merge.Nb_pers_household_2011 == merge.NBPERSM_2011)
assert np.all(merge.Nb_pers_household_2014 == merge.NBPERSM_2014)

# %%
merge.shape
# Out:
# (790413, 248)

# %%
result_path = u"C:/Users/IMPTEMP_A_PACIFIC/Desktop/EDP_2016/Program/Program_only_married_couples/hdf_married_couples/"

# %%
fiscr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 790495 entries, 0 to 790494
# Columns: 244 entries, ID_FISC_LOG_DIFF to Age_child_mean
# dtypes: bool(1), float64(115), int64(116), object(12)
# memory usage: 1.4+ GB

# %%
fiscr.to_hdf(result_path+"married_couples_step_2.h5", "fiscr")
# Out:
# C:\Users\IMPTEMP_A_PACIFIC\Desktop\WinPython-64bit-3.6.3.0Qt5\python-3.6.3.amd64\lib\site-packages\pandas\core\generic.py:1471: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed-integer,key->block3_values] [items->['ID_FISC_LOG_DIFF', 'DEP_2011', 'DEPCOM_2011', 'I_CHAMPM_2011', 'I_PAUVRE50M_2011', 'I_PAUVRE60M_2011', 'DEP_2014', 'DEPCOM_2014', 'I_PAUVRE50M_2014', 'I_PAUVRE60M_2014', 'TYPE_FISC_2011', 'TYPE_FISC_2014']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
stop_time = datetime.datetime.now(); print("now: ",stop_time);
execution_time = stop_time - start_time; print("execution_time: ",execution_time)
# Out:
# now:  2018-11-30 16:56:02.815762
# execution_time:  0:04:26.743650
